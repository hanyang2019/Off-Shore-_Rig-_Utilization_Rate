# %%
import pandas as pd

# %%
trans_df = pd.read_excel('transposed_RC.xlsx', sheet_name='Sheet2')

# %%
trans_df.head()
# Out:
#   Unnamed: 0 Type  1982-01-01 00:00:00  1982-02-01 00:00:00  \
# 0    Austria    L                 10.0                 10.0
# 1    Austria    O                  0.0                  0.0
# 2    Denmark    L                  0.0                  0.0
# 3    Denmark    O                  2.0                  2.0
# 4     France    L                 28.0                 28.0
#
#    1982-03-01 00:00:00  1982-04-01 00:00:00  1982-05-01 00:00:00  \
# 0                 10.0                  9.0                  9.0
# 1                  0.0                  0.0                  0.0
# 2                  0.0                  0.0                  0.0
# 3                  2.0                  2.0                  2.0
# 4                 26.0                 28.0                 28.0
#
#    1982-06-01 00:00:00  1982-07-01 00:00:00  1982-08-01 00:00:00  ...  \
# 0                  8.0                  8.0                  8.0  ...
# ...

# %%
land_df=trans_df[trans_df['Type']=='L']
land_df=land_df.drop('Type',axis=1)
land_df.set_index(['Unnamed: 0'], inplace=True)
trans_land=land_df.transpose()
headers=trans_land.columns.tolist()
df_list=[]
for column in headers:
    df=trans_land[[column]]
    df['nation']=column
    df.rename(columns={column:'Count'}, inplace=True)
    df_list.append(df)
new_land=pd.concat(df_list)
new_land.reset_index(drop=False, inplace=True)
new_land['Type']="In-Land"
new_land.rename(columns={'index':'Date','nation':'country'},inplace=True)
new_land
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Unnamed: 0       Date  Count       country     Type
# 0          1982-01-01   10.0       Austria  In-Land
# 1          1982-02-01   10.0       Austria  In-Land
# 2          1982-03-01   10.0       Austria  In-Land
# 3          1982-04-01    9.0       Austria  In-Land
# ...

# %%
shore_df=trans_df[trans_df['Type']=='O']
shore_df=shore_df.drop('Type',axis=1)
shore_df.set_index(['Unnamed: 0'], inplace=True)
trans_shore=shore_df.transpose()
headers=trans_shore.columns.tolist()
df_list=[]
for column in headers:
    df=trans_shore[[column]]
    df['nation']=column
    df.rename(columns={column:'Count'}, inplace=True)
    df_list.append(df)
new_shore=pd.concat(df_list)
new_shore.reset_index(drop=False, inplace=True)
new_shore['Type']="Off-Shore"
new_shore.rename(columns={'index':'Date','nation':'country'},inplace=True)
new_shore
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Unnamed: 0       Date  Count       country       Type
# 0          1982-01-01    0.0       Austria  Off-Shore
# 1          1982-02-01    0.0       Austria  Off-Shore
# 2          1982-03-01    0.0       Austria  Off-Shore
# 3          1982-04-01    0.0       Austria  Off-Shore
# 4          1982-05-01    0.0       Austria  Off-Shore
# 5          1982-06-01    0.0       Austria  Off-Shore
# 6          1982-07-01    0.0       Austria  Off-Shore
# 7          1982-08-01    0.0       Austria  Off-Shore
# 8          1982-09-01    0.0       Austria  Off-Shore
# 9          1982-10-01    0.0       Austria  Off-Shore
# ...

# %%
combine_df=pd.concat([new_land, new_shore])

# %%
combine_df.to_csv('RC_data.csv',index=False,header=True)
